# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('ai_financial_market_daily_realistic_synthetic.csv')
df.head()
# Out:
#          Date Company  R&D_Spending_USD_Mn  AI_Revenue_USD_Mn  \
# 0  2015-01-01  OpenAI                 5.92               0.63
# 1  2015-01-02  OpenAI                 5.41               1.81
# 2  2015-01-03  OpenAI                 4.50               0.61
# 3  2015-01-04  OpenAI                 5.45               0.95
# 4  2015-01-05  OpenAI                 3.40               1.48
#
#    AI_Revenue_Growth_% Event  Stock_Impact_%
# 0               -36.82   NaN           -0.36
# 1                80.59   NaN            0.41
# 2               -38.88   NaN            0.23
# 3                -5.34   NaN            0.93
# 4                48.45   NaN           -0.09

# %%
# Keep only rows where company is "OpenAI"
df = df[df['Company'] == "OpenAI"]

df.head()
# Out:
#          Date Company  R&D_Spending_USD_Mn  AI_Revenue_USD_Mn  \
# 0  2015-01-01  OpenAI                 5.92               0.63
# 1  2015-01-02  OpenAI                 5.41               1.81
# 2  2015-01-03  OpenAI                 4.50               0.61
# 3  2015-01-04  OpenAI                 5.45               0.95
# 4  2015-01-05  OpenAI                 3.40               1.48
#
#    AI_Revenue_Growth_% Event  Stock_Impact_%
# 0               -36.82   NaN           -0.36
# 1                80.59   NaN            0.41
# 2               -38.88   NaN            0.23
# 3                -5.34   NaN            0.93
# 4                48.45   NaN           -0.09

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 3653 entries, 0 to 3652
# Data columns (total 7 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Date                 3653 non-null   object
#  1   Company              3653 non-null   object
#  2   R&D_Spending_USD_Mn  3653 non-null   float64
#  3   AI_Revenue_USD_Mn    3653 non-null   float64
#  4   AI_Revenue_Growth_%  3653 non-null   float64
#  5   Event                78 non-null     object
#  6   Stock_Impact_%       3653 non-null   float64
# dtypes: float64(4), object(3)
# memory usage: 228.3+ KB

# %%
df
# Out:
#             Date Company  R&D_Spending_USD_Mn  AI_Revenue_USD_Mn  \
# 0     2015-01-01  OpenAI                 5.92               0.63
# 1     2015-01-02  OpenAI                 5.41               1.81
# 2     2015-01-03  OpenAI                 4.50               0.61
# 3     2015-01-04  OpenAI                 5.45               0.95
# 4     2015-01-05  OpenAI                 3.40               1.48
# ...          ...     ...                  ...                ...
# 3648  2024-12-27  OpenAI                10.06               4.71
# 3649  2024-12-28  OpenAI                 9.67               5.32
# 3650  2024-12-29  OpenAI                 9.17               5.46
# 3651  2024-12-30  OpenAI                10.36               6.31
# 3652  2024-12-31  OpenAI                10.24               4.92
#
#       AI_Revenue_Growth_% Event  Stock_Impact_%
# 0                  -36.82   NaN           -0.36
# 1                   80.59   NaN            0.41
# 2                  -38.88   NaN            0.23
# 3                   -5.34   NaN            0.93
# 4                   48.45   NaN           -0.09
# ...                   ...   ...             ...
# 3648               370.69   NaN            0.93
# 3649               432.15   NaN           -0.25
# 3650               445.74   NaN            0.47
# 3651               530.88   NaN            0.69
# 3652               391.69   NaN           -0.87
#
# [3653 rows x 7 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 3653 entries, 0 to 3652
# Data columns (total 7 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Date                 3653 non-null   object
#  1   Company              3653 non-null   object
#  2   R&D_Spending_USD_Mn  3653 non-null   float64
#  3   AI_Revenue_USD_Mn    3653 non-null   float64
#  4   AI_Revenue_Growth_%  3653 non-null   float64
#  5   Event                78 non-null     object
#  6   Stock_Impact_%       3653 non-null   float64
# dtypes: float64(4), object(3)
# memory usage: 228.3+ KB

# %%
df = df.drop(columns=['Date','Company'])

# %%
df["Stock_Impact_%"] = (df["Stock_Impact_%"] > 0).astype(int)

# %%
df
# Out:
#       R&D_Spending_USD_Mn  AI_Revenue_USD_Mn  AI_Revenue_Growth_% Event  \
# 0                    5.92               0.63               -36.82   NaN
# 1                    5.41               1.81                80.59   NaN
# 2                    4.50               0.61               -38.88   NaN
# 3                    5.45               0.95                -5.34   NaN
# 4                    3.40               1.48                48.45   NaN
# ...                   ...                ...                  ...   ...
# 3648                10.06               4.71               370.69   NaN
# 3649                 9.67               5.32               432.15   NaN
# 3650                 9.17               5.46               445.74   NaN
# 3651                10.36               6.31               530.88   NaN
# 3652                10.24               4.92               391.69   NaN
#
#       Stock_Impact_%
# 0                  0
# 1                  1
# 2                  1
# 3                  1
# 4                  0
# ...              ...
# 3648               1
# 3649               0
# 3650               1
# 3651               1
# 3652               0
#
# [3653 rows x 5 columns]

# %%
X = df[['R&D_Spending_USD_Mn','AI_Revenue_USD_Mn','AI_Revenue_Growth_%','Event']]
y= df['Stock_Impact_%']

# %%
X_numeric = df[['R&D_Spending_USD_Mn','AI_Revenue_USD_Mn','AI_Revenue_Growth_%']]

# %%
import numpy
print(numpy.__version__)
# Out:
# 1.26.4

# %%
from sentence_transformers import SentenceTransformer

# Load a pretrained model (downloads automatically, no manual files)
model = SentenceTransformer('all-MiniLM-L6-v2')  

# Example: embed your events
sentences = df['Event'].fillna("").astype(str).tolist()
event_embeddings = model.encode(sentences, convert_to_numpy=True)

print(event_embeddings.shape)  # (num_events, 384)
# Out:
# (3653, 384)

# %%
print(X_numeric.shape)
# Out:
# (3653, 3)

# %%
from sklearn.decomposition import PCA

# Reduce event embeddings from 384 → 50
pca = PCA(n_components=50, random_state=42)
event_embeddings_reduced = pca.fit_transform(event_embeddings)

print("Original:", event_embeddings.shape)
print("Reduced:", event_embeddings_reduced.shape)
# Out:
# Original: (3653, 384)
# Reduced: (3653, 50)

# %%
from sklearn.preprocessing import StandardScaler
import numpy as np

scaler = StandardScaler()
X_numeric_scaled = scaler.fit_transform(X_numeric)   # shape: (N_samples, 3)

# %%
def create_sequences(X_numeric, X_event, y, window=30):
    Xn_seq, Xe_seq, y_seq = [], [], []
    for i in range(len(X_numeric) - window):
        Xn_seq.append(X_numeric[i:i+window])
        Xe_seq.append(X_event[i:i+window])
        y_seq.append(y[i+window])   # predict next day impact
    return np.array(Xn_seq), np.array(Xe_seq), np.array(y_seq)

y = df['Stock_Impact_%'].values

Xn_seq, Xe_seq, y_seq = create_sequences(X_numeric_scaled, event_embeddings_reduced, y, window=30)

print(Xn_seq.shape)   # (N_samples, 30, 3)
# middle one is window size
print(Xe_seq.shape)   # (N_samples, 30, d)
print(y_seq.shape)    # (N_samples,)
# Out:
# (3623, 30, 3)
# (3623, 30, 50)
# (3623,)

# %%
Xe_seq
# Out:
# array([[[ 2.33695898e-02,  2.43170201e-04, -2.31901853e-04, ...,
#          -2.40023201e-08, -6.24206606e-08, -2.36706068e-08],
#         [ 2.33709645e-02,  2.48600467e-04, -2.37878456e-04, ...,
#           4.15682528e-08,  4.50311388e-09,  2.18951008e-08],
#         [ 2.33722143e-02,  2.45532923e-04, -2.35888248e-04, ...,
#          -4.16307415e-08,  1.90637877e-07,  1.43410247e-07],
#         ...,
#         [ 2.33721659e-02,  2.45650590e-04, -2.35531028e-04, ...,
#          -3.57998680e-08, -1.24720057e-08,  3.18314726e-08],
#         [ 2.33724136e-02,  2.46136566e-04, -2.35830856e-04, ...,
#          -1.71188308e-08,  9.65026903e-09, -1.36699541e-09],
#         [ 2.33724713e-02,  2.45988515e-04, -2.35745145e-04, ...,
#           1.35430875e-08,  2.75805045e-09,  4.46965664e-09]],
#
#        [[ 2.33709645e-02,  2.48600467e-04, -2.37878456e-04, ...,
#           4.15682528e-08,  4.50311388e-09,  2.18951008e-08],
#         [ 2.33722143e-02,  2.45532923e-04, -2.35888248e-04, ...,
#          -4.16307415e-08,  1.90637877e-07,  1.43410247e-07],
#         [ 2.33709104e-02,  2.45360483e-04, -2.34268606e-04, ...,
#           6.62788935e-08, -1.21082252e-07, -5.00673281e-08],
#         ...,
#         [ 2.33724136e-02,  2.46136566e-04, -2.35830856e-04, ...,
#          -1.71188308e-08,  9.65026903e-09, -1.36699541e-09],
#         [ 2.33724713e-02,  2.45988515e-04, -2.35745145e-04, ...,
#           1.35430875e-08,  2.75805045e-09,  4.46965664e-09],
#         [ 2.33726054e-02,  2.46036652e-04, -2.35708707e-04, ...,
#           1.91414795e-08, -1.93021759e-08, -1.48562744e-08]],
#
#        [[ 2.33722143e-02,  2.45532923e-04, -2.35888248e-04, ...,
#          -4.16307415e-08,  1.90637877e-07,  1.43410247e-07],
#         [ 2.33709104e-02,  2.45360483e-04, -2.34268606e-04, ...,
#           6.62788935e-08, -1.21082252e-07, -5.00673281e-08],
#         [ 2.33717933e-02,  2.47261196e-04, -2.38177148e-04, ...,
#           2.17778449e-07,  1.68976342e-07,  1.98335982e-07],
#         ...,
#         [ 2.33724713e-02,  2.45988515e-04, -2.35745145e-04, ...,
#           1.35430875e-08,  2.75805045e-09,  4.46965664e-09],
#         [ 2.33726054e-02,  2.46036652e-04, -2.35708707e-04, ...,
#           1.91414795e-08, -1.93021759e-08, -1.48562744e-08],
#         [ 2.33725607e-02,  2.45996343e-04, -2.35662141e-04, ...,
#           2.66675659e-08, -4.42769945e-08, -2.32686368e-08]],
#
#        ...,
#
#        [[ 2.33725365e-02,  2.45933246e-04, -2.35665633e-04, ...,
#           9.93876537e-10, -3.86459170e-10, -5.47278722e-10],
#         [ 2.33725365e-02,  2.45933246e-04, -2.35665633e-04, ...,
#           9.93876537e-10, -3.86459170e-10, -5.47278722e-10],
#         [ 2.33726986e-02,  2.46029231e-04, -2.35767555e-04, ...,
#           1.15316176e-07, -4.97741190e-08, -2.76549148e-08],
#         ...,
#         [ 2.33726092e-02,  2.45768810e-04, -2.35657440e-04, ...,
#          -1.02901039e-08,  7.28554417e-09,  5.79565622e-08],
#         [ 2.33720820e-02,  2.45843345e-04, -2.35379513e-04, ...,
#          -1.42487991e-07,  2.23310135e-08, -1.30296073e-07],
#         [ 2.33725291e-02,  2.45990377e-04, -2.35573825e-04, ...,
#           2.02142711e-08, -1.98892494e-08, -8.72752324e-08]],
#
#        [[ 2.33725365e-02,  2.45933246e-04, -2.35665633e-04, ...,
#           9.93876537e-10, -3.86459170e-10, -5.47278722e-10],
#         [ 2.33726986e-02,  2.46029231e-04, -2.35767555e-04, ...,
#           1.15316176e-07, -4.97741190e-08, -2.76549148e-08],
#         [ 2.33723409e-02,  2.45444069e-04, -2.35500309e-04, ...,
#          -6.41349729e-09,  3.63378483e-08,  9.59986934e-08],
#         ...,
#         [ 2.33720820e-02,  2.45843345e-04, -2.35379513e-04, ...,
#          -1.42487991e-07,  2.23310135e-08, -1.30296073e-07],
#         [ 2.33725291e-02,  2.45990377e-04, -2.35573825e-04, ...,
#           2.02142711e-08, -1.98892494e-08, -8.72752324e-08],
#         [ 2.33725235e-02,  2.45862990e-04, -2.35760352e-04, ...,
#          -8.01745892e-10, -4.19136335e-08,  1.97667418e-07]],
#
#        [[ 2.33726986e-02,  2.46029231e-04, -2.35767555e-04, ...,
#           1.15316176e-07, -4.97741190e-08, -2.76549148e-08],
#         [ 2.33723409e-02,  2.45444069e-04, -2.35500309e-04, ...,
#          -6.41349729e-09,  3.63378483e-08,  9.59986934e-08],
#         [ 2.33724862e-02,  2.45936069e-04, -2.35703235e-04, ...,
#           7.91308619e-09,  6.25794350e-09,  6.88801105e-09],
#         ...,
#         [ 2.33725291e-02,  2.45990377e-04, -2.35573825e-04, ...,
#           2.02142711e-08, -1.98892494e-08, -8.72752324e-08],
#         [ 2.33725235e-02,  2.45862990e-04, -2.35760352e-04, ...,
#          -8.01745892e-10, -4.19136335e-08,  1.97667418e-07],
#         [ 2.33730860e-02,  2.46071955e-04, -2.36044856e-04, ...,
#           1.04526620e-07,  7.33000363e-08,  2.23854926e-08]]],
#       dtype=float32)

# %%
Xn_seq
# Out:
# array([[[-0.70457346, -1.38434077, -1.3830652 ],
#         [-0.97483057, -0.55109965, -0.55398911],
#         [-1.45705404, -1.3984635 , -1.39761164],
#         ...,
#         [-1.65312292, -1.01714977, -1.01622675],
#         [-1.37756665, -1.2360521 , -1.23378772],
#         [-0.73636841, -0.95359748, -0.951827  ]],
#
#        [[-0.97483057, -0.55109965, -0.55398911],
#         [-1.45705404, -1.3984635 , -1.39761164],
#         [-0.95363393, -1.15837708, -1.1607731 ],
#         ...,
#         [-1.37756665, -1.2360521 , -1.23378772],
#         [-0.73636841, -0.95359748, -0.951827  ],
#         [-0.70987261, -1.54675217, -1.54759525]],
#
#        [[-1.45705404, -1.3984635 , -1.39761164],
#         [-0.95363393, -1.15837708, -1.1607731 ],
#         [-2.03996153, -0.78412471, -0.78094172],
#         ...,
#         [-0.73636841, -0.95359748, -0.951827  ],
#         [-0.70987261, -1.54675217, -1.54759525],
#         [-1.1126087 , -1.12307025, -1.12525438]],
#
#        ...,
#
#        [[ 1.32500445,  1.65910772,  1.65848106],
#         [ 1.97150185,  1.89919414,  1.89920335],
#         [ 1.10773893,  1.88507141,  1.88373893],
#         ...,
#         [ 1.51577417,  1.44020539,  1.44113192],
#         [ 1.48927838,  1.49669631,  1.49451592],
#         [ 1.28261118,  1.9274396 ,  1.92850805]],
#
#        [[ 1.97150185,  1.89919414,  1.89920335],
#         [ 1.10773893,  1.88507141,  1.88373893],
#         [ 2.06158755,  1.36959174,  1.37150676],
#         ...,
#         [ 1.48927838,  1.49669631,  1.49451592],
#         [ 1.28261118,  1.9274396 ,  1.92850805],
#         [ 1.01765323,  2.02629872,  2.02447215]],
#
#        [[ 1.10773893,  1.88507141,  1.88373893],
#         [ 2.06158755,  1.36959174,  1.37150676],
#         [ 0.8268835 ,  1.82151912,  1.82124576],
#         ...,
#         [ 1.28261118,  1.9274396 ,  1.92850805],
#         [ 1.01765323,  2.02629872,  2.02447215],
#         [ 1.64825315,  2.62651478,  2.62567765]]])

# %%
X
# Out:
#       R&D_Spending_USD_Mn  AI_Revenue_USD_Mn  AI_Revenue_Growth_% Event
# 0                    5.92               0.63               -36.82   NaN
# 1                    5.41               1.81                80.59   NaN
# 2                    4.50               0.61               -38.88   NaN
# 3                    5.45               0.95                -5.34   NaN
# 4                    3.40               1.48                48.45   NaN
# ...                   ...                ...                  ...   ...
# 3648                10.06               4.71               370.69   NaN
# 3649                 9.67               5.32               432.15   NaN
# 3650                 9.17               5.46               445.74   NaN
# 3651                10.36               6.31               530.88   NaN
# 3652                10.24               4.92               391.69   NaN
#
# [3653 rows x 4 columns]

# %%
y
# Out:
# array([0, 1, 1, ..., 1, 1, 0])

# %%
import pandas as pd
pd.Series(y).value_counts(normalize=True)
# Out:
# 1    0.500684
# 0    0.499316
# Name: proportion, dtype: float64

# %%
import numpy as np
import tensorflow as tf
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, LSTM, Dense, Concatenate, Dropout, BatchNormalization, Activation

# %%
# Shapes from your preprocessing
num_features = Xn_seq.shape[2]   # 3 numerical columns
event_dim = Xe_seq.shape[2]      # 384 from MiniLM

print(num_features)
print(event_dim)
# Out:
# 3
# 50

# %%
# --- Numerical branch ---
numeric_input = Input(shape=(30, num_features), name="numeric_input")
x1 = LSTM(256, return_sequences=False)(numeric_input)   # (batch, 64)
x1 = Dropout(0.1)(x1)

# %%
# --- Event (text embeddings) branch ---
event_input = Input(shape=(30, event_dim), name="event_input")
x2 = LSTM(64, return_sequences=False)(event_input)    # (batch, 64)
x2 = Dropout(0.1)(x2)

# %%
from tensorflow.keras.regularizers import l2
# --- Concatenate both branches ---
merged = Concatenate()([x1, x2])   # (batch, 128)

# Dense layers on top

dense = Dense(128, activation="relu" )(merged)
dense = Dropout(0.3)(dense)
dense = Dense(64, activation="relu")(dense)
dense = Dropout(0.3)(dense)
output = Dense(1, activation="sigmoid")(dense)
  # Regression → stock impact %

# %%
from sklearn.model_selection import train_test_split

# Split into train/test (e.g., 80/20 split)
Xn_train, Xn_test, Xe_train, Xe_test, y_train, y_test = train_test_split(
    Xn_seq, Xe_seq, y_seq, test_size=0.2, shuffle=False   # shuffle=False keeps time order
)

print(Xn_train.shape, Xe_train.shape, y_train.shape)
print(Xn_test.shape, Xe_test.shape, y_test.shape)
# Out:
# (2898, 30, 3) (2898, 30, 50) (2898,)
# (725, 30, 3) (725, 30, 50) (725,)

# %%
from tensorflow.keras.callbacks import EarlyStopping
es = EarlyStopping(patience=20, restore_best_weights=True)

# 1. Build + compile model (keep this part)
model = Model(inputs=[numeric_input, event_input], outputs=output)
model.compile(optimizer="Adam", loss="binary_crossentropy", metrics=["accuracy"])
model.summary()

# 2. Train
history = model.fit(
    [Xn_train, Xe_train], y_train,
    validation_data=([Xn_test, Xe_test], y_test),
    epochs=50,
    batch_size=32,
    # callbacks = [es]
)
# Out:
# Model: "functional_14"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ numeric_input       │ (None, 30, 3)     │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ event_input         │ (None, 30, 50)    │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ lstm_28 (LSTM)      │ (None, 256)       │    266,240 │ numeric_input[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ lstm_29 (LSTM)      │ (None, 64)        │     29,440 │ event_input[0][0] │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_52          │ (None, 256)       │          0 │ lstm_28[0][0]     │
# │ (Dropout)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_53          │ (None, 64)        │          0 │ lstm_29[0][0]     │
# │ (Dropout)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_13      │ (None, 320)       │          0 │ dropout_52[0][0], │
# │ (Concatenate)       │                   │            │ dropout_53[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_37 (Dense)    │ (None, 128)       │     41,088 │ concatenate_13[0… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_54          │ (None, 128)       │          0 │ dense_37[0][0]    │
# │ (Dropout)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_38 (Dense)    │ (None, 64)        │      8,256 │ dropout_54[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_55          │ (None, 64)        │          0 │ dense_38[0][0]    │
# │ (Dropout)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_39 (Dense)    │ (None, 1)         │         65 │ dropout_55[0][0]  │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 345,089 (1.32 MB)
#  Trainable params: 345,089 (1.32 MB)
#  Non-trainable params: 0 (0.00 B)
# Epoch 1/100
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 4s 28ms/step - accuracy: 0.5117 - loss: 0.6953 - val_accuracy: 0.4979 - val_loss: 0.7422
# Epoch 2/100
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 3s 28ms/step - accuracy: 0.5083 - loss: 0.6951 - val_accuracy: 0.4979 - val_loss: 0.6950
# Epoch 3/100
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 2s 27ms/step - accuracy: 0.5186 - loss: 0.6934 - val_accuracy: 0.5021 - val_loss: 0.7071
# Epoch 4/100
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 3s 35ms/step - accuracy: 0.4841 - loss: 0.6974 - val_accuracy: 0.4869 - val_loss: 0.6937
# Epoch 5/100
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 2s 26ms/step - accuracy: 0.5138 - loss: 0.6934 - val_accuracy: 0.4979 - val_loss: 0.6945
# Epoch 6/100
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 3s 28ms/step - accuracy: 0.4985 - loss: 0.6932 - val_accuracy: 0.5048 - val_loss: 0.6937
# Epoch 7/100
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 2s 25ms/step - accuracy: 0.4691 - loss: 0.6947 - val_accuracy: 0.4924 - val_loss: 0.6936
# Epoch 8/100
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 4s 46ms/step - accuracy: 0.5028 - loss: 0.6935 - val_accuracy: 0.4869 - val_loss: 0.6933
# Epoch 9/100
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 3s 31ms/step - accuracy: 0.5199 - loss: 0.6936 - val_accuracy: 0.4938 - val_loss: 0.6931
# Epoch 10/100
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 3s 28ms/step - accuracy: 0